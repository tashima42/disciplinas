# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("registros_aves_curitiba.csv")
cbro = pd.read_csv("cbro-lista-aves.csv", sep=";")

# %%
df_familias = pd.merge(cbro, df, on='nome_vernaculo')
df_familias.to_csv("registros-com-familia.csv")

# %%
df_familias
# Out:
#          #              nome-taxon    autoria     ano            ordem  \
# 0     3435   Mionectes rufiventris    Cabanis  1846.0    Passeriformes
# 1     1271       Pandion haliaetus   Linnaeus  1758.0  Accipitriformes
# 2     3717  Serpophaga subcristata   Vieillot  1817.0    Passeriformes
# 3     3717  Serpophaga subcristata   Vieillot  1817.0    Passeriformes
# 4     3717  Serpophaga subcristata   Vieillot  1817.0    Passeriformes
# ...    ...                     ...        ...     ...              ...
# 8306  3967   Hylophilus poicilotis   Temminck  1822.0    Passeriformes
# 8307  3967   Hylophilus poicilotis   Temminck  1822.0    Passeriformes
# 8308  3967   Hylophilus poicilotis   Temminck  1822.0    Passeriformes
# 8309  2703       Sclerurus scansor  Ménétries  1835.0    Passeriformes
# 8310  2703       Sclerurus scansor  Ménétries  1835.0    Passeriformes
#
#      subordem   infraordem   parvordem  superfamilia          familia  ...  \
# ...
