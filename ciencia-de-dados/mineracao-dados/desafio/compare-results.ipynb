# %%
import pandas as pd

df_one = pd.read_csv("data/tree-2.csv")
df_two = pd.read_csv("data/tree-3.csv")

df_one.compare(df_two)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def ch(r):
    if r == 0: 
        return 1; 
    return 0
df_two["destaque"] = df_two["destaque"].apply(ch)
df_two.set_index("business_id", inplace=True)

# %%
df_two.to_csv("data/respostas-5.csv")
